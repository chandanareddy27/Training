# %%
a = "Chandana \nReddy"
print(a)
# Out:
# Chandana
# Reddy

# %%
set1={56,2,"a",2,78.9}
print(set1)
# Out:
# {56, 2, 78.9, 'a'}

# %%
set2={56,2,"a",2}
print(set2)
# Out:
# {56, 2, 'a'}

# %%
dict1={"key1":1,"key2":2}
print(dict1)
print(dict1.keys())
print(dict1.values())
# Out:
# {'key1': 1, 'key2': 2}
# dict_keys(['key1', 'key2'])
# dict_values([1, 2])

# %%
def add():
    return 34+36
result=add()
print(result)
# Out:
# 70

# %%
from datetime import date
year=int(input("Enter the year: "))
current_year = date.today().year
age =current_year - year
print(age)
# Out:
# Enter the year:  2006
# 19

# %%
year=int(input("Enter the year: "))
age = 2025 - year
print(age)
# Out:
# Enter the year:  2006
# 19

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
requests.get("https://www.geeksforgeeks.org/aptitude/aptitude-questions-and-answers/")
# Out:
# <Response [200]>

# %%
data=requests.get("https://www.geeksforgeeks.org/aptitude/aptitude-questions-and-answers/")
print(data.text)
# Out:
# <!DOCTYPE html><html lang="en"><head><link rel="preconnect" href="https://fonts.googleapis.com"/><link rel="preconnect" href="https://fonts.gstatic.com" crossorigin="true"/><meta charSet="UTF-8"/><meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=0.5, maximum-scale=3.0"/><meta name="robots" content="index, follow, max-image-preview:large, max-snippet:-1"/><link rel="shortcut icon" href="https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_favicon.png" type="image/x-icon"/><meta name="theme-color" content="#308D46"/><meta name="image" property="og:image" content="https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_200x200-min.png"/><meta property="og:image:type" content="image/png"/><meta property="og:image:width" content="200"/><meta property="og:image:height" content="200"/><meta name="facebook-domain-verification" content="xo7t4ve2wn3ywfkjdvwbrk01pvdond"/><meta property="og:title" content="Aptitude Questions and Answers - GeeksforGeeks"
# ...

# %%
requests.get("https://www.geeksforgeeks.org/javascript/web-api-url/")
# Out:
# <Response [200]>

# %%
data=requests.get("https://www.geeksforgeeks.org/javascript/web-api-url/")
print(data.text)
# Out:
# <!DOCTYPE html>
# <!--[if IE 7]>
# <html class="ie ie7" lang="en-US">
# <![endif]-->
# <!--[if IE 8]>
# <html class="ie ie8" lang="en-US">
# <![endif]-->
# <!--[if !(IE 7) | !(IE 8)  ]><!-->
# <html lang="en-US" >
#
# <!--<![endif]-->
# <head>
# <meta charset="UTF-8" />
#
# <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=0.5, maximum-scale=3.0">
# <meta name='robots' content='index, follow, max-image-preview:large, max-snippet:-1' /><link rel="shortcut icon" href="https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_favicon.png" type="image/x-icon" />
#
# <link rel="preconnect" href="https://fonts.googleapis.com">
# <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>
#
#
# <meta name="theme-color" content="#308D46" />
# <!-- <meta name='robots' content='index, follow, max-image-preview:large, max-snippet:-1' /> -->
#
# ...
